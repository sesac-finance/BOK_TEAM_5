# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('./infomax_crawling/newscrawler/infomax_mp.csv')

# %%
df.head()
# Out:
#          date                                       title  \
# 0  2022.10.04                  [도쿄환시] 달러-엔 144엔대 유지…재료 혼재
# 1  2022.10.06                   통상본부장 "수출 둔화·무역적자 엄중히 인식"
# 2  2022.10.12               미 국채가 하락…FOMC의사록·인플레 지표에 시선집중
# 3  2022.10.04  '빅쇼트' 모델 데니 모세스 "버냉키가 거품 조장… 밈 주식 무너져야 바닥"
# 4  2022.09.28               뉴욕증시, 국채금리 상승에 혼조…다우 0.43%↓마감
#
#                                              content
# 0  \n    달러-엔 환율 추이[출처: 연합인포맥스]\n\n\n(서울=연합인포맥스) ...
# 1  \n    답변하는 안덕근 산업통상자원부 통상교섭본부장(서울=연합뉴스) 하사헌 기자...
# 2  \r\n\t\r\n\t\t\r\n\t\t\r\n\t(뉴욕=연합인포맥스) 정선영 특파...
# 3  \r\n\t\r\n\t\t\r\n\t\t\r\n\t(뉴욕=연합인포맥스) 배수연 특파...
# 4  \n    NYSE 입회장에 트레이더의 모습(뉴욕=연합뉴스) 윤영숙 연합인포맥스 특...

# %%
print(df.date)
# Out:
# 0        2022.10.04
# 1        2022.10.06
# 2        2022.10.12
# 3        2022.10.04
# 4        2022.09.28
#             ...
# 49300    2011.12.05
# 49301    2011.12.14
# 49302    2011.12.14
# 49303    2011.12.14
# 49304    2011.12.14
# Name: date, Length: 49305, dtype: object

# %%
date2 = set(df.date)

# %%
sorted(date2)
# Out:
# ['2011.01.20',
#  '2011.01.24',
#  '2011.01.26',
#  '2011.02.02',
#  '2011.02.03',
#  '2011.02.05',
#  '2011.02.08',
#  '2011.02.10',
#  '2011.02.19',
#  '2011.02.22',
#  '2011.02.23',
#  '2011.02.25',
#  '2011.03.01',
#  '2011.03.03',
#  '2011.03.10',
#  '2011.03.12',
#  '2011.03.14',
#  '2011.03.16',
#  '2011.03.22',
#  '2011.03.23',
#  '2011.03.29',
#  '2011.03.30',
#  '2011.04.02',
#  '2011.04.04',
#  '2011.04.06',
#  '2011.04.07',
#  '2011.04.08',
#  '2011.04.11',
#  '2011.04.14',
#  '2011.04.15',
#  '2011.04.21',
#  '2011.04.27',
#  '2011.04.28',
#  '2011.05.02',
#  '2011.05.03',
#  '2011.05.04',
#  '2011.05.05',
#  '2011.05.09',
#  '2011.05.11',
#  '2011.05.18',
#  '2011.06.01',
#  '2011.06.08',
#  '2011.06.09',
#  '2011.06.10',
#  '2011.06.30',
#  '2011.07.01',
#  '2011.07.05',
#  '2011.07.07',
#  '2011.07.08',
#  '2011.08.04',
#  '2011.08.05',
#  '2011.08.08',
#  '2011.09.08',
#  '2011.09.21',
#  '2011.09.30',
#  '2011.10.05',
#  '2011.10.06',
#  '2011.10.07',
# ...

# %%
print(df.title)
# Out:
# 0                        [도쿄환시] 달러-엔 144엔대 유지…재료 혼재
# 1                         통상본부장 "수출 둔화·무역적자 엄중히 인식"
# 2                     미 국채가 하락…FOMC의사록·인플레 지표에 시선집중
# 3        '빅쇼트' 모델 데니 모세스 "버냉키가 거품 조장… 밈 주식 무너져야 바닥"
# 4                     뉴욕증시, 국채금리 상승에 혼조…다우 0.43%↓마감
#                             ...
# 49300                  "유로화, ECB 회의 이전에 저가매수하라"<씨티>
# 49301              <고침>Fed, 미국 경제 전망 소폭 상향…기존 정책 유지
# 49302                   FOMC 향후 정책 가이드없어..유로화 낙폭 확대
# 49303                  Fed, 미국 경제 전망 소폭 상향…기존 정책 유지
# 49304             <뉴욕환시> 유로화, 메르켈 발언으로 11개월래 최저치 급락
# Name: title, Length: 49305, dtype: object
